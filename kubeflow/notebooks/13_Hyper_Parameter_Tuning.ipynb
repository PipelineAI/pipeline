# %%
# !kubectl create -f hyperparameter-tuning/random-search-job.yaml

# %% [markdown]
# # Check out the Parameter Optimizations tab
#
# ![Successful Hyperparameter Tuning](https://pipeline.ai/assets/img/successful-hyperparameter-tuning.png)
#
# ![Successful Hyperparameter Tuning](https://pipeline.ai/assets/img/successful-hyperparameter-tuning-2.png)
