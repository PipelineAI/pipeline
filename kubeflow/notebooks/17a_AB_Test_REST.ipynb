# %%
# !kubectl create -f deployments/abtest-model.yaml

# %%
# !cat deployments/abtest-model.yaml

# %% [markdown]
# # Change the following `<ip-address>`

# %%
# %%bash
#
# curl http://35.225.234.167/seldon/kubeflow/abtest-model/api/v0.1/predictions -d '{"data":{"names":["a","b"],"tensor":{"shape":[2,2],"values":[0,0,1,1]}}}' -H "Content-Type: application/json"
