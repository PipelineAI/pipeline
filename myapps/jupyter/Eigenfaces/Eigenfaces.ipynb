# %% [markdown]
# This demo was heavily inspired by this book...
#
# ![Machine Learning with Spark](http://advancedspark.com/img/machine-learning-with-spark.png)

# %% [markdown]
# ### Eigenfaces generated with the Zeppelin Notebook here:
# * http://[your-public-ip]:8080/#/notebook/2BJVSQ3J6

# %%
import matplotlib.pyplot as plt
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def plot_gallery(images, h, w, n_row=2, n_col=5):
    """Helper function to plot a gallery of portraits"""
    plt.figure(figsize=(1.8*n_col, 2.5*n_row))
    plt.subplots_adjust(bottom=0, left=0.01, right=0.99, top=0.90, hspace=0.35)
    for i in range(n_row * n_col):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[:, i].reshape((h, w)), cmap=plt.cm.gray)
        plt.title("Eigenface %d" % (i + 1), size=12)
        plt.xticks(())
        plt.yticks(())

# %%
name = "Jennifer_Capriati"

# %%
originalImageFilename = "/root/pipeline/datasets/eigenface/lfw-deepfunneled/%s/%s_0001.jpg" % (name, name)
imshow(imread(originalImageFilename))

# %% [markdown]
# ### Eigenfaces:  Facial Principal Components

# %%
pcgwb = np.loadtxt("/tmp/%s/principal-components.csv" % name, delimiter=",")
print(pcgwb.shape)
plot_gallery(pcgwb, 50, 50)
# Out:
# (2500, 10)
