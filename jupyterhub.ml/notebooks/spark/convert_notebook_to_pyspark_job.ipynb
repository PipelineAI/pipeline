# %%
# !jupyter nbconvert \
  /root/volumes/source.ml/jupyterhub.ml/notebooks/spark/pyspark_pi.ipynb \
  --to script \
  --output-dir=/root/volumes/source.ml/jupyterhub.ml/scripts/spark/
# Out:
# [NbConvertApp] Converting notebook /root/volumes/source.ml/jupyterhub.ml/notebooks/spark/pyspark_pi.ipynb to script
# [NbConvertApp] Writing 501 bytes to /root/volumes/source.ml/jupyterhub.ml/scripts/spark/pyspark_pi.py

# %%
cat /root/volumes/source.ml/jupyterhub.ml/scripts/spark/pyspark_pi.py
# Out:
# # coding: utf-8
#
# # In[7]:
#
# import sys
# from random import random
# from operator import add
#
# from pyspark.sql import SparkSession
#
# spark = SparkSession.builder.appName("PythonPi").getOrCreate()
#
# partitions = 100
# n = 100000 * partitions
#
# def f(_):
#     x = random() * 2 - 1
#     y = random() * 2 - 1
#     return 1 if x ** 2 + y ** 2 <= 1 else 0
#
# count = spark.sparkContext.parallelize(range(1, n + 1), partitions).map(f).reduce(add)
# print("Pi is roughly %f" % (4.0 * count / n))
#
# spark.stop()
#
#
# # In[ ]:

# %%
# !spark-submit --master spark://spark-master-2-1-0:7077 \
  /root/volumes/source.ml/jupyterhub.ml/scripts/spark/pyspark_pi.py
# Out:
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# 17/03/08 22:35:17 INFO SparkContext: Running Spark version 2.0.1
# 17/03/08 22:35:17 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 17/03/08 22:35:18 INFO SecurityManager: Changing view acls to: root
# 17/03/08 22:35:18 INFO SecurityManager: Changing modify acls to: root
# 17/03/08 22:35:18 INFO SecurityManager: Changing view acls groups to:
# 17/03/08 22:35:18 INFO SecurityManager: Changing modify acls groups to:
# 17/03/08 22:35:18 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(root); groups with view permissions: Set(); users  with modify permissions: Set(root); groups with modify permissions: Set()
# 17/03/08 22:35:18 INFO Utils: Successfully started service 'sparkDriver' on port 44222.
# 17/03/08 22:35:18 INFO SparkEnv: Registering MapOutputTracker
# ...
